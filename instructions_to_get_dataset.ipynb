# %% [markdown]
# # Instructions
#
# 1. Go to your Kaggle Account page
# 2. Press "Create New API token"
# 3. A `kaggle.json` file will be downloaded after pressing
# 4. Take note of the username and key values (this will be asked in the 2nd code cell)
#
# and if you still cant get it then just follow this [link](https://medium.com/international-school-of-ai-data-science/how-to-access-datasets-directly-from-kaggle-97db4eecb2f6) until the "Setting things up" section

# %%
# !pip install opendatasets --upgrade --quiet
import opendatasets as od
import pandas as pd

# %%
dataset = 'https://www.kaggle.com/datasets/arunavakrchakraborty/covid19-twitter-dataset?resource=download&select=Covid-19+Twitter+Dataset+%28Aug-Sep+2020%29.csv'

od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: intechllectualbeing
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 58.0M/58.0M [00:01<00:00, 43.2MB/s]

# %%
df1 = pd.read_csv("/content/covid19-twitter-dataset/Covid-19 Twitter Dataset (Apr-Jun 2020).csv")
df2 = pd.read_csv("/content/covid19-twitter-dataset/Covid-19 Twitter Dataset (Aug-Sep 2020).csv")

df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#                   id                      created_at  \
# 0       1.250000e+18  Sun Apr 19 21:21:54 +0000 2020
# 1       1.250000e+18  Sun Apr 19 21:21:53 +0000 2020
# 2       1.250000e+18  Sun Apr 19 21:21:52 +0000 2020
# 3       1.250000e+18  Sun Apr 19 21:21:51 +0000 2020
# 4       1.250000e+18  Sun Apr 19 21:21:50 +0000 2020
# ...              ...                             ...
# 555551  1.320000e+18  Tue Oct 20 20:35:43 +0000 2020
# 555552  1.320000e+18  Tue Oct 20 20:35:42 +0000 2020
# 555553  1.320000e+18  Tue Oct 20 20:35:41 +0000 2020
# 555554  1.320000e+18  Tue Oct 20 20:35:40 +0000 2020
# 555555  1.320000e+18  Tue Oct 20 20:35:39 +0000 2020
#
#                                                    source  \
# 0       <a href="http://twitter.com/download/android" ...
# 1       <a href="http://twitter.com/download/android" ...
# 2       <a href="http://twitter.com/download/iphone" r...
# 3       <a href="http://twitter.com/download/iphone" r...
# ...
